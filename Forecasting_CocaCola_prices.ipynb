# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammed-Fayaz-Ahamed/DataScience_assignment/blob/main/Forecasting_CocaCola_prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CocaCola prices
# Forecast the CocaCola prices and Airlines Passengers data set. Prepare a document for each model explaining
# how many dummy variables you have created
# and RMSE value for each model. Finally which model you will use for
# Forecasting.

# %%
# Import the file
import pandas as pd

co = pd.read_excel("/content/CocaCola_Sales_Rawdata.xlsx")
co
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# 37   Q2_95  4936.000000
# 38   Q3_95  4895.000000
# 39   Q4_95  4333.000000
# 40   Q1_96  4194.000000
# 41   Q2_96  5253.000000

# %%
co.isnull().sum()
# Out:
# Quarter    0
# Sales      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
co.Sales.plot()
# Out:
# <Axes: >

# %%
co.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Quarter  42 non-null     object
#  1   Sales    42 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 800.0+ bytes

# %%
co.describe()
# Out:
#              Sales
# count    42.000000
# mean   2994.353308
# std     977.930896
# min    1547.818996
# 25%    2159.714247
# 50%    2782.376999
# 75%    3609.250000
# max    5253.000000

# %%
co['Quarter_Year'] = co['Quarter'].str.split('_').apply(lambda x: ' 19'.join(x[:]))
#Clean way to convert quarterly periods to datetime in pandas
co
# Out:
#    Quarter        Sales Quarter_Year
# 0    Q1_86  1734.827000      Q1 1986
# 1    Q2_86  2244.960999      Q2 1986
# 2    Q3_86  2533.804993      Q3 1986
# 3    Q4_86  2154.962997      Q4 1986
# 4    Q1_87  1547.818996      Q1 1987
# 5    Q2_87  2104.411995      Q2 1987
# 6    Q3_87  2014.362999      Q3 1987
# 7    Q4_87  1991.746998      Q4 1987
# 8    Q1_88  1869.049999      Q1 1988
# 9    Q2_88  2313.631996      Q2 1988
# 10   Q3_88  2128.320000      Q3 1988
# 11   Q4_88  2026.828999      Q4 1988
# 12   Q1_89  1910.603996      Q1 1989
# 13   Q2_89  2331.164993      Q2 1989
# 14   Q3_89  2206.549995      Q3 1989
# 15   Q4_89  2173.967995      Q4 1989
# 16   Q1_90  2148.278000      Q1 1990
# 17   Q2_90  2739.307999      Q2 1990
# 18   Q3_90  2792.753998      Q3 1990
# 19   Q4_90  2556.009995      Q4 1990
# 20   Q1_91  2480.973999      Q1 1991
# 21   Q2_91  3039.522995      Q2 1991
# 22   Q3_91  3172.115997      Q3 1991
# 23   Q4_91  2879.000999      Q4 1991
# 24   Q1_92  2772.000000      Q1 1992
# 25   Q2_92  3550.000000      Q2 1992
# 26   Q3_92  3508.000000      Q3 1992
# 27   Q4_92  3243.859993      Q4 1992
# 28   Q1_93  3056.000000      Q1 1993
# 29   Q2_93  3899.000000      Q2 1993
# 30   Q3_93  3629.000000      Q3 1993
# 31   Q4_93  3373.000000      Q4 1993
# 32   Q1_94  3352.000000      Q1 1994
# 33   Q2_94  4342.000000      Q2 1994
# 34   Q3_94  4461.000000      Q3 1994
# 35   Q4_94  4017.000000      Q4 1994
# 36   Q1_95  3854.000000      Q1 1995
# 37   Q2_95  4936.000000      Q2 1995
# 38   Q3_95  4895.000000      Q3 1995
# 39   Q4_95  4333.000000      Q4 1995
# 40   Q1_96  4194.000000      Q1 1996
# 41   Q2_96  5253.000000      Q2 1996

# %%
# converting into datetime formate as the index was not in correct formate.
co['Date'] = (
    pd.to_datetime(
        co['Quarter_Year'].str.split(' ').apply(lambda x: ''.join(x[::-1]))
,dayfirst=True))

co['Quarters'] = 0

for i in range(42):                                   # seperating the Quarter
    n = co['Quarter'][i]
    co['Quarters'][i] = n[0:2]

dummy = pd.DataFrame(pd.get_dummies(co['Quarters']))  # Creating dummy
co = pd.concat((co, dummy), axis=1)
co.drop(['Quarter','Quarter_Year'] , axis =1, inplace = True)
co
# Out:
# <ipython-input-7-b31692ccc66f>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co['Quarters'][i] = n[0:2]
#           Sales       Date Quarters  Q1  Q2  Q3  Q4
# 0   1734.827000 1986-01-01       Q1   1   0   0   0
# 1   2244.960999 1986-04-01       Q2   0   1   0   0
# 2   2533.804993 1986-07-01       Q3   0   0   1   0
# 3   2154.962997 1986-10-01       Q4   0   0   0   1
# 4   1547.818996 1987-01-01       Q1   1   0   0   0
# 5   2104.411995 1987-04-01       Q2   0   1   0   0
# 6   2014.362999 1987-07-01       Q3   0   0   1   0
# 7   1991.746998 1987-10-01       Q4   0   0   0   1
# 8   1869.049999 1988-01-01       Q1   1   0   0   0
# 9   2313.631996 1988-04-01       Q2   0   1   0   0
# 10  2128.320000 1988-07-01       Q3   0   0   1   0
# 11  2026.828999 1988-10-01       Q4   0   0   0   1
# 12  1910.603996 1989-01-01       Q1   1   0   0   0
# 13  2331.164993 1989-04-01       Q2   0   1   0   0
# 14  2206.549995 1989-07-01       Q3   0   0   1   0
# 15  2173.967995 1989-10-01       Q4   0   0   0   1
# 16  2148.278000 1990-01-01       Q1   1   0   0   0
# 17  2739.307999 1990-04-01       Q2   0   1   0   0
# 18  2792.753998 1990-07-01       Q3   0   0   1   0
# 19  2556.009995 1990-10-01       Q4   0   0   0   1
# 20  2480.973999 1991-01-01       Q1   1   0   0   0
# 21  3039.522995 1991-04-01       Q2   0   1   0   0
# 22  3172.115997 1991-07-01       Q3   0   0   1   0
# 23  2879.000999 1991-10-01       Q4   0   0   0   1
# 24  2772.000000 1992-01-01       Q1   1   0   0   0
# 25  3550.000000 1992-04-01       Q2   0   1   0   0
# 26  3508.000000 1992-07-01       Q3   0   0   1   0
# 27  3243.859993 1992-10-01       Q4   0   0   0   1
# 28  3056.000000 1993-01-01       Q1   1   0   0   0
# 29  3899.000000 1993-04-01       Q2   0   1   0   0
# 30  3629.000000 1993-07-01       Q3   0   0   1   0
# 31  3373.000000 1993-10-01       Q4   0   0   0   1
# 32  3352.000000 1994-01-01       Q1   1   0   0   0
# 33  4342.000000 1994-04-01       Q2   0   1   0   0
# 34  4461.000000 1994-07-01       Q3   0   0   1   0
# 35  4017.000000 1994-10-01       Q4   0   0   0   1
# 36  3854.000000 1995-01-01       Q1   1   0   0   0
# 37  4936.000000 1995-04-01       Q2   0   1   0   0
# 38  4895.000000 1995-07-01       Q3   0   0   1   0
# 39  4333.000000 1995-10-01       Q4   0   0   0   1
# 40  4194.000000 1996-01-01       Q1   1   0   0   0
# 41  5253.000000 1996-04-01       Q2   0   1   0   0

# %%
co["Date"] = pd.to_datetime(co.Date,format="%b-%y")
co["month"] = co.Date.dt.strftime("%b") # month extraction
co["year"] = co.Date.dt.strftime("%Y") # year extraction
co
# Out:
#           Sales       Date Quarters  Q1  Q2  Q3  Q4 month  year
# 0   1734.827000 1986-01-01       Q1   1   0   0   0   Jan  1986
# 1   2244.960999 1986-04-01       Q2   0   1   0   0   Apr  1986
# 2   2533.804993 1986-07-01       Q3   0   0   1   0   Jul  1986
# 3   2154.962997 1986-10-01       Q4   0   0   0   1   Oct  1986
# 4   1547.818996 1987-01-01       Q1   1   0   0   0   Jan  1987
# 5   2104.411995 1987-04-01       Q2   0   1   0   0   Apr  1987
# 6   2014.362999 1987-07-01       Q3   0   0   1   0   Jul  1987
# 7   1991.746998 1987-10-01       Q4   0   0   0   1   Oct  1987
# 8   1869.049999 1988-01-01       Q1   1   0   0   0   Jan  1988
# 9   2313.631996 1988-04-01       Q2   0   1   0   0   Apr  1988
# 10  2128.320000 1988-07-01       Q3   0   0   1   0   Jul  1988
# 11  2026.828999 1988-10-01       Q4   0   0   0   1   Oct  1988
# 12  1910.603996 1989-01-01       Q1   1   0   0   0   Jan  1989
# 13  2331.164993 1989-04-01       Q2   0   1   0   0   Apr  1989
# 14  2206.549995 1989-07-01       Q3   0   0   1   0   Jul  1989
# 15  2173.967995 1989-10-01       Q4   0   0   0   1   Oct  1989
# 16  2148.278000 1990-01-01       Q1   1   0   0   0   Jan  1990
# 17  2739.307999 1990-04-01       Q2   0   1   0   0   Apr  1990
# 18  2792.753998 1990-07-01       Q3   0   0   1   0   Jul  1990
# 19  2556.009995 1990-10-01       Q4   0   0   0   1   Oct  1990
# 20  2480.973999 1991-01-01       Q1   1   0   0   0   Jan  1991
# 21  3039.522995 1991-04-01       Q2   0   1   0   0   Apr  1991
# 22  3172.115997 1991-07-01       Q3   0   0   1   0   Jul  1991
# 23  2879.000999 1991-10-01       Q4   0   0   0   1   Oct  1991
# 24  2772.000000 1992-01-01       Q1   1   0   0   0   Jan  1992
# 25  3550.000000 1992-04-01       Q2   0   1   0   0   Apr  1992
# 26  3508.000000 1992-07-01       Q3   0   0   1   0   Jul  1992
# 27  3243.859993 1992-10-01       Q4   0   0   0   1   Oct  1992
# 28  3056.000000 1993-01-01       Q1   1   0   0   0   Jan  1993
# 29  3899.000000 1993-04-01       Q2   0   1   0   0   Apr  1993
# 30  3629.000000 1993-07-01       Q3   0   0   1   0   Jul  1993
# 31  3373.000000 1993-10-01       Q4   0   0   0   1   Oct  1993
# 32  3352.000000 1994-01-01       Q1   1   0   0   0   Jan  1994
# 33  4342.000000 1994-04-01       Q2   0   1   0   0   Apr  1994
# 34  4461.000000 1994-07-01       Q3   0   0   1   0   Jul  1994
# 35  4017.000000 1994-10-01       Q4   0   0   0   1   Oct  1994
# 36  3854.000000 1995-01-01       Q1   1   0   0   0   Jan  1995
# 37  4936.000000 1995-04-01       Q2   0   1   0   0   Apr  1995
# 38  4895.000000 1995-07-01       Q3   0   0   1   0   Jul  1995
# 39  4333.000000 1995-10-01       Q4   0   0   0   1   Oct  1995
# 40  4194.000000 1996-01-01       Q1   1   0   0   0   Jan  1996
# 41  5253.000000 1996-04-01       Q2   0   1   0   0   Apr  1996

# %%
co['Sales'].plot(figsize=(10, 8),color='blue',marker='o')
plt.show()

# %%
#Histogram
co.Sales.hist()
# Out:
# <Axes: >

# %%
#Density plot and Lag plot
co.Sales.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# scatter plot
from pandas.plotting import lag_plot
lag_plot(co.Sales)
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %%
# create an autocorrelation plot
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(co.Sales,lags=40)

# %%
# Box plot for every

import seaborn as sns
plt.figure(figsize=(8,6))
plt.subplot(211)
sns.boxplot(x="Quarters", y="Sales" ,data = co)

plt.subplot(212)
sns.boxplot(x="year", y="Sales" ,data = co)
# Out:
# <Axes: xlabel='year', ylabel='Sales'>

# %% [markdown]
# ## Splitting data

# %%
co.set_index('Date',inplace=True)
co.index.year
# Out:
# Int64Index([1986, 1986, 1986, 1986, 1987, 1987, 1987, 1987, 1988, 1988, 1988,
#             1988, 1989, 1989, 1989, 1989, 1990, 1990, 1990, 1990, 1991, 1991,
#             1991, 1991, 1992, 1992, 1992, 1992, 1993, 1993, 1993, 1993, 1994,
#             1994, 1994, 1994, 1995, 1995, 1995, 1995, 1996, 1996],
#            dtype='int64', name='Date')

# %%
upsampled_month = co.drop(['Quarters','Q1','Q2','Q3','Q4'], axis=1)
upsampled_month = upsampled_month.resample('M').mean()
print(upsampled_month.head(13))
# Out:
#                   Sales
# Date
# 1986-01-31  1734.827000
# 1986-02-28          NaN
# 1986-03-31          NaN
# 1986-04-30  2244.960999
# 1986-05-31          NaN
# 1986-06-30          NaN
# 1986-07-31  2533.804993
# 1986-08-31          NaN
# 1986-09-30          NaN
# 1986-10-31  2154.962997
# 1986-11-30          NaN
# 1986-12-31          NaN
# 1987-01-31  1547.818996
# <ipython-input-30-c9191ae98b52>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   upsampled_month = upsampled_month.resample('M').mean()

# %%
interpolated_month = upsampled_month.interpolate(method='linear') ## interplation was done for nan values which we get after doing upsampling by month
print(interpolated_month.head(15))
interpolated_month.plot(figsize=(12,8))
plt.show()
# Out:
#                   Sales
# Date
# 1986-01-31  1734.827000
# 1986-02-28  1904.871666
# 1986-03-31  2074.916332
# 1986-04-30  2244.960999
# 1986-05-31  2341.242330
# 1986-06-30  2437.523661
# 1986-07-31  2533.804993
# 1986-08-31  2407.524328
# 1986-09-30  2281.243663
# 1986-10-31  2154.962997
# 1986-11-30  1952.581664
# 1986-12-31  1750.200330
# 1987-01-31  1547.818996
# 1987-02-28  1733.349996
# 1987-03-31  1918.880995

# %%
train_data = interpolated_month[:100]
test_data = interpolated_month[100:]

# %%
import numpy as np

interpolated_month.reset_index(inplace=True)
interpolated_month['t'] = np.arange(1,len(interpolated_month)+1)
interpolated_month['t_squared'] = np.square(interpolated_month.t)
interpolated_month["month"] = interpolated_month.Date.dt.strftime("%b") # month extraction
interpolated_month["year"] = interpolated_month.Date.dt.strftime("%Y") # year extraction
months = pd.get_dummies(interpolated_month['month'])
months = months[['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']]
cocacola = pd.concat([interpolated_month,months],axis=1)
cocacola['log_sales'] = np.log(cocacola['Sales'])
cocacola
# Out:
#           Date        Sales    t  t_squared month  year  Jan  Feb  Mar  Apr  \
# 0   1986-01-31  1734.827000    1          1   Jan  1986    1    0    0    0
# 1   1986-02-28  1904.871666    2          4   Feb  1986    0    1    0    0
# 2   1986-03-31  2074.916332    3          9   Mar  1986    0    0    1    0
# 3   1986-04-30  2244.960999    4         16   Apr  1986    0    0    0    1
# 4   1986-05-31  2341.242330    5         25   May  1986    0    0    0    0
# ..         ...          ...  ...        ...   ...   ...  ...  ...  ...  ...
# 119 1995-12-31  4240.333333  120      14400   Dec  1995    0    0    0    0
# 120 1996-01-31  4194.000000  121      14641   Jan  1996    1    0    0    0
# 121 1996-02-29  4547.000000  122      14884   Feb  1996    0    1    0    0
# 122 1996-03-31  4900.000000  123      15129   Mar  1996    0    0    1    0
# 123 1996-04-30  5253.000000  124      15376   Apr  1996    0    0    0    1
#
#      May  Jun  Jul  Aug  Sep  Oct  Nov  Dec  log_sales
# 0      0    0    0    0    0    0    0    0   7.458663
# 1      0    0    0    0    0    0    0    0   7.552170
# 2      0    0    0    0    0    0    0    0   7.637676
# 3      0    0    0    0    0    0    0    0   7.716443
# 4      1    0    0    0    0    0    0    0   7.758437
# ..   ...  ...  ...  ...  ...  ...  ...  ...        ...
# 119    0    0    0    0    0    0    0    1   8.352397
# 120    0    0    0    0    0    0    0    0   8.341410
# 121    0    0    0    0    0    0    0    0   8.422223
# 122    0    0    0    0    0    0    0    0   8.496990
# 123    0    0    0    0    0    0    0    0   8.566555
#
# [124 rows x 19 columns]

# %%
size = 100

train_data = cocacola.iloc[:size]
test_data = cocacola.iloc[size:]

# %%
# Linear model
import statsmodels.formula.api as smf

linear_model = smf.ols('Sales~t',data=train_data).fit()
pred_linear =  pd.Series(linear_model.predict(pd.DataFrame(test_data['t'])))
rmse_linear = np.sqrt(np.mean((np.array(test_data['Sales'])-np.array(pred_linear))**2))
rmse_linear
# Out:
# 686.8740863668942

# %%
#Exponential

Exp = smf.ols('log_sales~t',data=train_data).fit()
pred_Exp = pd.Series(Exp.predict(pd.DataFrame(test_data['t'])))
rmse_Exp = np.sqrt(np.mean((np.array(test_data['Sales'])-np.array(np.exp(pred_Exp)))**2))
rmse_Exp
# Out:
# 530.326802509923

# %%
#Quadratic

Quad = smf.ols('Sales~t+t_squared',data=train_data).fit()
pred_Quad = pd.Series(Quad.predict(test_data[["t","t_squared"]]))
rmse_Quad = np.sqrt(np.mean((np.array(test_data['Sales'])-np.array(pred_Quad))**2))
rmse_Quad
# Out:
# 371.29418344986675

# %%
#Additive seasonality


add_sea = smf.ols('Sales~Jan+Feb+Mar+Apr+May+Jun+Jul+Aug+Sep+Oct+Nov+Dec',data=train_data).fit()
pred_add_sea = pd.Series(add_sea.predict(test_data[['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']]))
rmse_add_sea = np.sqrt(np.mean((np.array(test_data['Sales'])-np.array(pred_add_sea))**2))
rmse_add_sea
# Out:
# 1837.7879723483793

# %%
#Additive Seasonality Quadratic

add_sea_Quad = smf.ols('Sales~t+t_squared+Jan+Feb+Mar+Apr+May+Jun+Jul+Aug+Sep+Oct+Nov+Dec',data=train_data).fit()
pred_add_sea_quad = pd.Series(add_sea_Quad.predict(test_data[['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec','t','t_squared']]))
rmse_add_sea_quad = np.sqrt(np.mean((np.array(test_data['Sales'])-np.array(pred_add_sea_quad))**2))
rmse_add_sea_quad
# Out:
# 225.8049881036695

# %%
##Multiplicative Seasonality

Mul_sea = smf.ols('log_sales~Jan+Feb+Mar+Apr+May+Jun+Jul+Aug+Sep+Oct+Nov+Dec',data = train_data).fit()
pred_Mult_sea = pd.Series(Mul_sea.predict(test_data))
rmse_Mult_sea = np.sqrt(np.mean((np.array(test_data['Sales'])-np.array(np.exp(pred_Mult_sea)))**2))
rmse_Mult_sea
# Out:
# 1904.7944171920315

# %%
#Multiplicative Additive Seasonality


Mul_Add_sea = smf.ols('log_sales~t+Jan+Feb+Mar+Apr+May+Jun+Jul+Aug+Sep+Oct+Nov+Dec',data = train_data).fit()
pred_Mult_add_sea = pd.Series(Mul_Add_sea.predict(test_data))
rmse_Mult_add_sea = np.sqrt(np.mean((np.array(test_data['Sales'])-np.array(np.exp(pred_Mult_add_sea)))**2))
rmse_Mult_add_sea
# Out:
# 396.41978173823406

# %%
#Compare the results

data = {"Models":pd.Series(["rmse_linear","rmse_Exp","rmse_Quad","rmse_add_sea","rmse_add_sea_quad","rmse_Mult_sea","rmse_Mult_add_sea"]),"RMSE_Values":pd.Series([rmse_linear,rmse_Exp,rmse_Quad,rmse_add_sea,rmse_add_sea_quad,rmse_Mult_sea,rmse_Mult_add_sea])}
table_rmse=pd.DataFrame(data)
table_rmse.sort_values(['RMSE_Values'], inplace=True, ignore_index=True)

# %%
f, axe = plt.subplots(1,1, figsize=(12,5), dpi=100)
sns.barplot(x='RMSE_Values', y='Models', data=table_rmse, ax = axe)
axe.set_xlabel('Different_Models', size=16)
axe.set_ylabel('RMSE', size=16)
plt.yticks(fontsize=12,fontweight = 'bold')
plt.xticks(fontsize=18)

for i, v in enumerate(np.round(table_rmse.RMSE_Values.values,0)):
    axe.text(v + 3, i + .25, str(v),
            color = 'black', fontweight = 'bold', fontsize= 12)

plt.show()

# %% [markdown]
# From the graph we can say that the rmse value is less for the Additive Seasonality Quadratic model
